# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import loader2
import os
import torch
import pandas as pd
from torch import nn
from torch.utils.data import DataLoader
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
import sklearn.metrics
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier
import pickle
import numpy as np
import datetime

# %%
# Running time calculate: start time
start_time = datetime.datetime.now()
# Detection

# Diagnosis 
class waveformDiagnosisDL:
    
    def __init__(self, path):
        
        # Directory of normal and abnormal data
        normal_path = path + 'Normal/'
        fault_1_path = path + 'Fault_A/'
        fault_2_path = path + 'Fault_AE/'
        fault_3_path = path + 'Fault_B/'
        fault_4_path = path + 'Fault_C/'
        fault_5_path = path + 'Fault_D/'
        
        
        normal_files = [f for f in os.listdir(normal_path) if f.endswith('.csv')]
        fault_1_files = [f for f in os.listdir(fault_1_path) if f.endswith('.csv')]
        fault_2_files = [f for f in os.listdir(fault_2_path) if f.endswith('.csv')]
        fault_3_files = [f for f in os.listdir(fault_3_path) if f.endswith('.csv')]
        fault_4_files = [f for f in os.listdir(fault_4_path) if f.endswith('.csv')]
        fault_5_files = [f for f in os.listdir(fault_5_path) if f.endswith('.csv')]
        
        np_normal = []
        np_fault_1 = []
        np_fault_2 = []
        np_fault_3 = []
        np_fault_4 = []
        np_fault_5 = []        
        
        for f in normal_files:
            temp_file = np.loadtxt(normal_path + f, delimiter=',', dtype=np.float32)
            np_normal.append(temp_file)
        
        for f in fault_1_files:
            temp_file = np.loadtxt(fault_1_path + f, delimiter=',', dtype=np.float32)
            np_fault_1.append(temp_file)
            
        for f in fault_2_files:
            temp_file = np.loadtxt(fault_2_path + f, delimiter=',', dtype=np.float32)
            np_fault_2.append(temp_file)
            
        for f in fault_3_files:
            temp_file = np.loadtxt(fault_3_path + f, delimiter=',', dtype=np.float32)
            np_fault_3.append(temp_file)
            
        for f in fault_4_files:
            temp_file = np.loadtxt(fault_4_path + f, delimiter=',', dtype=np.float32)
            np_fault_4.append(temp_file)
            
        for f in fault_5_files:
            temp_file = np.loadtxt(fault_5_path + f, delimiter=',', dtype=np.float32)
            np_fault_5.append(temp_file)

            
        # x: input data, y: target
        self.y_data = np.concatenate([np.zeros(len(np_normal),dtype=np.long), \
                                      np.zeros(len(np_fault_1),dtype=np.long)+1, \
                                      np.zeros(len(np_fault_2),dtype=np.long)+2, \
                                      np.zeros(len(np_fault_3),dtype=np.long)+3, \
                                      np.zeros(len(np_fault_4),dtype=np.long)+4, \
                                      np.zeros(len(np_fault_5),dtype=np.long)+5, ])
        self.x_data = np.concatenate([np_normal, np_fault_1, np_fault_2, np_fault_3, np_fault_4, 
                                      np_fault_5])
        self.len = self.x_data.shape[0]
        self.x_data = torch.from_numpy(self.x_data)
        self.y_data = torch.from_numpy(self.y_data)
    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index]
    def __len__(self):
        return self.len

# %%
data_path_DL = '/Users/Kayvon/Google Drive/reference_code/w20_newdataset/fault_diagnosis/deep_learning/'
all_data_DL = waveformDiagnosisDL(data_path_DL)

# %%
#%%----------------------create the LSTM Net ------------------------------------
class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()
        
        self.lstm = nn.LSTM(
                input_size=INPUT_SIZE,
                hidden_size=64,
                num_layers=10,
                batch_first=True,
                )
        
        self.out = nn.Linear(64, 6)
    
    def forward(self, x):
        lstm_out, (h_n, h_c) = self.lstm(x, None)
        out = self.out(lstm_out[:, -1, :])
        return out
    
data_output = {'lstm':{'F1':[], 'precision':[], 'recall':[], 'accuracy':[], 'auc':[], 'fpr':[], 'tpr':[], 'test_loss':[], 'train_loss':[]}}

# %%
EPOCH = 250
BATCH_SIZE = 512
TIME_STEP = 20
INPUT_SIZE = 408
LR = 0.0001
KFOLD = 1
isGPU = torch.cuda.is_available()

# %%
for num_of_training in range(KFOLD):
    print('------------------fold {}------------------------'.format(num_of_training + 1))
    lstm = LSTM()
    
    if isGPU:
        lstm = nn.DataParallel(lstm, device_ids=[0])
        lstm.cuda()

    lstm_optimizer = torch.optim.Adam(lstm.parameters(), lr=LR)
    # lstm_optimizer = torch.optim.SGD(lstm.parameters(), lr=LR)
    loss_func = nn.CrossEntropyLoss()
    
    # print the structure of the network
    print(lstm)
    
    # data partition: 15% testing, 85% training
    training_data, test_data = torch.utils.data.random_split(all_data_DL, [int(all_data_DL.len * 0.85), all_data_DL.len - int(all_data_DL.len * 0.85)])
    training_Loader = DataLoader(dataset=training_data, batch_size=BATCH_SIZE, shuffle=True)
    test_Loader = DataLoader(dataset=test_data, batch_size=BATCH_SIZE)
    
    # training and testing
    lstm_test_loss_draw = []
    
    lstm_loss_draw = []
    
    for epoch in range(EPOCH):
        print('-----------------------epoch {}----------------------'.format(epoch + 1))
        
        # training-----------------------------------------
        lstm_train_loss = 0.
        
        lstm_train_acc = 0.
        
        lstm.train()
        
        for step, (batch_x, batch_y) in enumerate(training_Loader):
            batch_x = batch_x.view(-1, TIME_STEP, INPUT_SIZE)
            
            if isGPU:
                batch_x = batch_x.cuda()
                batch_y = batch_y.cuda()

            output_lstm = lstm(batch_x)
          
            loss_lstm = loss_func(output_lstm, batch_y)
            
            lstm_train_loss += loss_lstm.item()
            
            
            
            if isGPU:
                lstm_pred = torch.max(output_lstm, 1)[1].cuda()
            else:
                lstm_pred = torch.max(output_lstm, 1)[1]
            
            lstm_train_correct = (lstm_pred == batch_y).sum()
            
            lstm_train_acc += lstm_train_correct.item()
            
            lstm_optimizer.zero_grad()
            
            loss_lstm.backward()
            
            lstm_optimizer.step()
            
        print('LSTM:\n Train Loss: {:.6f}, Accuracy: {:.6f}\n'.format(lstm_train_loss / 
              (len(training_data)), lstm_train_acc / (len(training_data))))
        
        lstm_loss_draw.append(lstm_train_loss/(len(training_data)))
        
        
        # evaluation--------------------------------------------------
        lstm.eval()
        
        lstm_eval_loss = 0.
        
        lstm_eval_acc = 0.
        
        lstm_final_prediction = np.array([])
        lstm_final_test = np.array([])
        lstm_f1_score = []
        lstm_recall = []
        lstm_precision = []
        lstm_accuracy = []
      
        for step, (batch_x, batch_y) in enumerate(test_Loader):
            batch_x = batch_x.view(-1, TIME_STEP, INPUT_SIZE)
            
            if isGPU:
                batch_x = batch_x.cuda()
                batch_y = batch_y.cuda()
    
            output_lstm = lstm(batch_x)
            
            loss_lstm = loss_func(output_lstm, batch_y)
            
            lstm_eval_loss += loss_lstm.item()
            
            lstm_pred = torch.max(output_lstm, 1)[1]
            
            lstm_eval_correct = (lstm_pred == batch_y).sum()
            
            
            if isGPU:
                lstm_pred = torch.max(output_lstm, 1)[1].cuda()
            else:
                lstm_pred = torch.max(output_lstm, 1)[1]
            
            lstm_eval_acc += lstm_eval_correct.item()
                      
            # F1 metrics
            lstm_final_prediction = np.concatenate((lstm_final_prediction, lstm_pred.cpu().numpy()), axis=0)
            lstm_final_test = np.concatenate((lstm_final_test, batch_y), axis=0)
        
        lstm_f1_score.append(sklearn.metrics.f1_score(lstm_final_test, lstm_final_prediction, average='weighted').item())
        lstm_recall.append(sklearn.metrics.recall_score(lstm_final_test, lstm_final_prediction, average='macro').item())
        lstm_precision.append(sklearn.metrics.precision_score(lstm_final_test, lstm_final_prediction, average='weighted').item())
        lstm_accuracy.append(lstm_eval_acc / (len(test_data)))

        
        print('LSTM:\n Test Loss: {:.6f}, Accuracy: {:.6f}'.format(lstm_eval_loss / (len(test_data)), lstm_eval_acc / (len(test_data))))
        
        lstm_test_loss_draw.append(lstm_eval_loss/(len(test_data)))
        
        print('LSTM:\n F1: {}, recall: {}, precision: {}'.format(lstm_f1_score[-1], lstm_recall[-1], lstm_precision[-1]))
        
    
    lstm_test_y = label_binarize(lstm_final_test, classes=[0, 1, 2, 3, 4, 5])
    lstm_pred_y = label_binarize(lstm_final_prediction, classes=[0, 1, 2, 3, 4, 5])
    
    lstm_fpr, lstm_tpr, _ = roc_curve(lstm_test_y.ravel(), lstm_pred_y.ravel())
    lstm_roc_auc = auc(lstm_fpr, lstm_tpr)
    
    
    data_output['lstm']['F1'].append(lstm_f1_score[-1])
    data_output['lstm']['precision'].append(lstm_precision[-1])
    data_output['lstm']['recall'].append(lstm_recall[-1])
    data_output['lstm']['accuracy'].append(lstm_accuracy[-1])
    data_output['lstm']['auc'].append(lstm_roc_auc.item())
    data_output['lstm']['fpr'].append(list(lstm_fpr))
    data_output['lstm']['tpr'].append(list(lstm_tpr))
    data_output['lstm']['test_loss'].append(lstm_test_loss_draw)
    data_output['lstm']['train_loss'].append(lstm_loss_draw)
# Out:
# ------------------fold 1------------------------
# LSTM(
#   (lstm): LSTM(408, 64, num_layers=10, batch_first=True)
#   (out): Linear(in_features=64, out_features=6, bias=True)
# )
# -----------------------epoch 1----------------------
# LSTM:
#  Train Loss: 0.003711, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010431, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 2----------------------
# /Users/Kayvon/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# LSTM:
#  Train Loss: 0.003709, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010427, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 3----------------------
# LSTM:
#  Train Loss: 0.003708, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010423, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 4----------------------
# LSTM:
#  Train Loss: 0.003706, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010418, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 5----------------------
# LSTM:
#  Train Loss: 0.003704, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010414, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 6----------------------
# LSTM:
#  Train Loss: 0.003703, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010410, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 7----------------------
# LSTM:
#  Train Loss: 0.003701, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010406, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 8----------------------
# LSTM:
#  Train Loss: 0.003700, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010401, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 9----------------------
# LSTM:
#  Train Loss: 0.003698, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010397, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 10----------------------
# LSTM:
#  Train Loss: 0.003697, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010393, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 11----------------------
# LSTM:
#  Train Loss: 0.003695, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010388, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 12----------------------
# LSTM:
#  Train Loss: 0.003694, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010383, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 13----------------------
# LSTM:
#  Train Loss: 0.003692, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010379, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 14----------------------
# LSTM:
#  Train Loss: 0.003690, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010374, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 15----------------------
# LSTM:
#  Train Loss: 0.003689, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010369, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 16----------------------
# LSTM:
#  Train Loss: 0.003687, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010364, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 17----------------------
# LSTM:
#  Train Loss: 0.003685, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010359, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 18----------------------
# LSTM:
#  Train Loss: 0.003683, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010353, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 19----------------------
# LSTM:
#  Train Loss: 0.003681, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010348, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 20----------------------
# LSTM:
#  Train Loss: 0.003679, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010342, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 21----------------------
# LSTM:
#  Train Loss: 0.003677, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010335, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 22----------------------
# LSTM:
#  Train Loss: 0.003675, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010329, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 23----------------------
# LSTM:
#  Train Loss: 0.003673, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010322, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 24----------------------
# LSTM:
#  Train Loss: 0.003670, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010314, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 25----------------------
# LSTM:
#  Train Loss: 0.003667, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010306, Accuracy: 0.202312
# LSTM:
#  F1: 0.06808581591818587, recall: 0.16666666666666666, precision: 0.04093020147682849
# -----------------------epoch 26----------------------
# LSTM:
#  Train Loss: 0.003664, Accuracy: 0.148718
#
# LSTM:
#  Test Loss: 0.010297, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 27----------------------
# LSTM:
#  Train Loss: 0.003661, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010288, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 28----------------------
# LSTM:
#  Train Loss: 0.003658, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010277, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 29----------------------
# LSTM:
#  Train Loss: 0.003654, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010265, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 30----------------------
# LSTM:
#  Train Loss: 0.003650, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010252, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 31----------------------
# LSTM:
#  Train Loss: 0.003645, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010237, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 32----------------------
# LSTM:
#  Train Loss: 0.003639, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010220, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 33----------------------
# LSTM:
#  Train Loss: 0.003634, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010202, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 34----------------------
# LSTM:
#  Train Loss: 0.003627, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010182, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 35----------------------
# LSTM:
#  Train Loss: 0.003619, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010161, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 36----------------------
# LSTM:
#  Train Loss: 0.003612, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010140, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 37----------------------
# LSTM:
#  Train Loss: 0.003605, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010123, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 38----------------------
# LSTM:
#  Train Loss: 0.003601, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010111, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 39----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010107, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 40----------------------
# LSTM:
#  Train Loss: 0.003599, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010109, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 41----------------------
# LSTM:
#  Train Loss: 0.003598, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010112, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 42----------------------
# LSTM:
#  Train Loss: 0.003599, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010112, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 43----------------------
# LSTM:
#  Train Loss: 0.003601, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010109, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 44----------------------
# LSTM:
#  Train Loss: 0.003598, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010104, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 45----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010099, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 46----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010097, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 47----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010096, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 48----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010095, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 49----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010095, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 50----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010094, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 51----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010094, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 52----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010094, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 53----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010093, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 54----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010092, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 55----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 56----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 57----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 58----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 59----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 60----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 61----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 62----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 63----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 64----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 65----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 66----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 67----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 68----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 69----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 70----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 71----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 72----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 73----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 74----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 75----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 76----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 77----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 78----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 79----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 80----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 81----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 82----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 83----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 84----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 85----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 86----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 87----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 88----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 89----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 90----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 91----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 92----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010088, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 93----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010087, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 94----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 95----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 96----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 97----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 98----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 99----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 100----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 101----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 102----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 103----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 104----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 105----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 106----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 107----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 108----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 109----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 110----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 111----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 112----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 113----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 114----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 115----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 116----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 117----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 118----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 119----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 120----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 121----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 122----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 123----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 124----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 125----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 126----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 127----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 128----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 129----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 130----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 131----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 132----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 133----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 134----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 135----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 136----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 137----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 138----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 139----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 140----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 141----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 142----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 143----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 144----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 145----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 146----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 147----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 148----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 149----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 150----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 151----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 152----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 153----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 154----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 155----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 156----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 157----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 158----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 159----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 160----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 161----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 162----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 163----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 164----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 165----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 166----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 167----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 168----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 169----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 170----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 171----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 172----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 173----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 174----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 175----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 176----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 177----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 178----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 179----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 180----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 181----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 182----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 183----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 184----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 185----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 186----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 187----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 188----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 189----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 190----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 191----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 192----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 193----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 194----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 195----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 196----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 197----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 198----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 199----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 200----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 201----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 202----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 203----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 204----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 205----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 206----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 207----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 208----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 209----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 210----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 211----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010089, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 212----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 213----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 214----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 215----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 216----------------------
# LSTM:
#  Train Loss: 0.003593, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 217----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 218----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 219----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 220----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 221----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 222----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 223----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 224----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 225----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 226----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 227----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 228----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 229----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 230----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 231----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 232----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 233----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 234----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 235----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 236----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 237----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 238----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 239----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 240----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 241----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 242----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 243----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 244----------------------
# LSTM:
#  Train Loss: 0.003595, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 245----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 246----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 247----------------------
# LSTM:
#  Train Loss: 0.003597, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 248----------------------
# LSTM:
#  Train Loss: 0.003594, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 249----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010090, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
# -----------------------epoch 250----------------------
# LSTM:
#  Train Loss: 0.003596, Accuracy: 0.266667
#
# LSTM:
#  Test Loss: 0.010091, Accuracy: 0.277457
# LSTM:
#  F1: 0.12052415452619465, recall: 0.16666666666666666, precision: 0.0769821911858064
