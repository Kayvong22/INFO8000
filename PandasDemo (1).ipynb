# %%
import pandas as pd
import matplotlib

# %%
df1 = pd.DataFrame({"name":["Kyle","Erin"],"number":[1234,5678]})

# %%
df2 = pd.DataFrame(
    columns = ["A","B","C"],
    data = [
        [1,2,3],
        [4,5,6],
        [7,8,9]],
)
df2 = df2.set_index(["A"]);

# %%
display(df1,df2)
# Out:
#    name  number
# 0  Kyle    1234
# 1  Erin    5678
#    B  C
# A
# 1  2  3
# 4  5  6
# 7  8  9

# %%
irisdf = pd.read_csv("iris.data",names=["Sepal Length","Sepal Width","Petal Length","Petal Width","Class"])

# %%
irisdf
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
irisdf.to_csv("temp.csv",index = False)

# %%
untidy_phone = pd.DataFrame({"names":["Kyle","Erin","Catherine","Claire"],
                             "MobileNumber":[4,1,2,1],
                             "HomeNumber":[6,3,5,None]}
                           )
untidy_phone.melt(id_vars=["names"],var_name="PhoneType",value_name="PhoneNumber")
# Out:
#        names     PhoneType  PhoneNumber
# 0       Kyle  MobileNumber          4.0
# 1       Erin  MobileNumber          1.0
# 2  Catherine  MobileNumber          2.0
# 3     Claire  MobileNumber          1.0
# 4       Kyle    HomeNumber          6.0
# 5       Erin    HomeNumber          3.0
# 6  Catherine    HomeNumber          5.0
# 7     Claire    HomeNumber          NaN

# %%
df3 = df2.assign(D=df2.B*df2.C)

# %%
# OR
df3['E'] = df2.B*df2.C

# %%
df1
# Out:
#    name  number
# 0  Kyle    1234
# 1  Erin    5678

# %%
df1 = df1.append(pd.DataFrame({"name":["Catherine"], "number":[5423]}),ignore_index=True)

# %%
df1[['name','number']]
# You have to use [[two brackets]] to get a DataFrame, if you type df1.name you get a series
# Out:
#         name  number
# 0       Kyle    1234
# 1       Erin    5678
# 2  Catherine    5423

# %% [markdown]
# df1

# %%
df1
# Out:
#         name  number
# 0       Kyle    1234
# 1       Erin    5678
# 2  Catherine    5423

# %%
untidy_phone
# Out:
#        names  MobileNumber  HomeNumber
# 0       Kyle             4         6.0
# 1       Erin             1         3.0
# 2  Catherine             2         5.0
# 3     Claire             1         NaN

# %%
untidy_phone.loc[0:2,'MobileNumber':'HomeNumber']
# Out:
#    MobileNumber  HomeNumber
# 0             4         6.0
# 1             1         3.0
# 2             2         5.0

# %%
b = untidy_phone.MobileNumber==1
display(b)
untidy_phone[(untidy_phone.MobileNumber == 4) & (untidy_phone.HomeNumber > 4)]
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: MobileNumber, dtype: bool
#   names  MobileNumber  HomeNumber
# 0  Kyle             4         6.0

# %%
irisdf.tail()
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           Class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
irisdf.sample(frac=0.5)
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width            Class
# 65            6.7          3.1           4.4          1.4  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 108           6.7          2.5           5.8          1.8   Iris-virginica
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 135           7.7          3.0           6.1          2.3   Iris-virginica
# ..            ...          ...           ...          ...              ...
# 96            5.7          2.9           4.2          1.3  Iris-versicolor
# 25            5.0          3.0           1.6          0.2      Iris-setosa
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# 78            6.0          2.9           4.5          1.5  Iris-versicolor
# 31            5.4          3.4           1.5          0.4      Iris-setosa
#
# [75 rows x 5 columns]

# %%
#This will give you a random sample of 50% of the data#

# %%
irisdf.nlargest(5,'Petal Width')
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           Class
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica

# %%
irisdf.sum()
# Out:
# Sepal Length                                                876.5
# Sepal Width                                                 458.1
# Petal Length                                                563.8
# Petal Width                                                 179.8
# Class           Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
irisdf.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
irisdf = irisdf.sample(10)
irisdf.describe(include = 'all')
display(irisdf.groupby(by = 'Class').rank(method = 'max'))
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width
# 63            2.0          3.0           2.0          2.0
# 98            1.0          2.0           1.0          1.0
# 109           2.0          2.0           2.0          2.0
# 9             1.0          1.0           4.0          1.0
# 35            3.0          2.0           1.0          4.0
# 15            5.0          5.0           4.0          5.0
# 72            3.0          2.0           3.0          3.0
# 106           1.0          1.0           1.0          1.0
# 7             3.0          4.0           4.0          4.0
# 20            4.0          4.0           5.0          4.0

# %%
irisdf = pd.read_csv("iris.data",names=["Sepal Length","Sepal Width","Petal Length","Petal Width","Class"])
irisdf.rolling(2,min_periods = 1).sum()
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width
# 0             5.1          3.5           1.4          0.2
# 1            10.0          6.5           2.8          0.4
# 2             9.6          6.2           2.7          0.4
# 3             9.3          6.3           2.8          0.4
# 4             9.6          6.7           2.9          0.4
# ..            ...          ...           ...          ...
# 145          13.4          6.3          10.9          4.8
# 146          13.0          5.5          10.2          4.2
# 147          12.8          5.5          10.2          3.9
# 148          12.7          6.4          10.6          4.3
# 149          12.1          6.4          10.5          4.1
#
# [150 rows x 4 columns]

# %%
irisdf.iloc[1,1] = None

# %%
#sepal_wid_mean = sepal_wid.mean()
#irisdf.fillna({"Sepal Width":sepal_wid_mean})

# %%
irisdf.plot.scatter('Sepal Width', "Sepal Length", s = [15], c = 'purple')
